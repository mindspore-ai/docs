# %% [markdown]
# # 快速入门：MindPandas数据处理
#
# [![查看源文件](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_source.png)](https://gitee.com/mindspore/docs/blob/master/docs/mindpandas/docs/source_zh_cn/mindpandas_quick_start.ipynb)
#
# 数据预处理对于模型训练非常重要，好的特征工程可以大幅度提升训练精度。本章节以推荐系统的特征工程为例，介绍使用MindPandas处理数据的流程。
#
# ## MindPandas后端设置
#
# MindPandas使用首先需要设置后端为multithread模式（如需使用yr模式，请参考[MindPandas后端执行模式配置及性能介绍](https://www.mindspore.cn/mindpandas/docs/zh-CN/master/mindpandas_configuration.html)），并设置切片维度为16*3，示例如下：

# %%
import hashlib

import numpy as np
import mindpandas as pd

pd.set_adaptive_concurrency(False)
pd.set_concurrency_mode("multithread")
pd.set_partition_shape((16, 3))

# %% [markdown]
# ## 下载并读取数据
#
# 下载[示例数据集](https://gitee.com/mindspore/mindpandas/tree/master/tests/st/data),该数据集包含用户的历史网页点击数据、以及被点击网页的分类和主题等信息。使用如下命令读取data2.csv文件。

# %%
file_name = "data/data2.csv"
mdf = pd.read_csv(file_name)

# %% [markdown]
# data2.csv文件是一个10000行、41列的二维数组，包含字符串、数字等数据。CSV原始数据输出如下：

# %%
mdf.to_pandas()
# Out:
#        user_id    doc_id  lang_type  domain_website      pt_d  \
# 0     19265380  96764505   85593781        66614410  87156290
# 1     85493911  87828698   98232131        41549241  48135212
# 2     28783123  64871036   95277574        42539942  30658195
# 3     79702669  12454864   71934373         4087017  32475645
# 4     56578946  62761265   43209571        96948416  80057523
# ...        ...       ...        ...             ...       ...
# 9995  99836239  33382142   47424555        84061856  48850740
# 9996  72990782  90103899   69145205        33555186  54606213
# 9997  82847429   9802771   40045859        82857068  41498974
# 9998  11936407  90919619   47759544        40296987  90955464
# 9999  72234883  43691775   29356767         5176795  52016923
#
#        url_drop_last_slash                   url            event_time  \
# 0     mlY5VQiTj8tKG9XNUPqr  n5v0zTX2QWsSZiYCaIg9  qtmxuICEXp3lAYc81KUh
# 1     i0t2AEukzZVljs53ro6c  AqWU9slEbd8Vai1GyI0T  wAO3Krq0b4mtgG58hykD
# 2     f529MPhI6FCjGdJSsLYN  TfY53EqVZl07s4PAxbHW  582pskLef7cWwgBQC3Xo
# 3     Yx1c8kPSol5grQ06y7su  o7KMWtxpXAsfh6ZPGLD9  SYrs72pBMVywlP0NQDEJ
# 4     ptjJvfT4bq8DYrN3QdmM  1n0cZ4PCa2jKxE9qpwOM  kpiNSEC7fXG4hy9FsWgL
# ...                    ...                   ...                   ...
# 9995  vmrMxVwPtg1BTYhDSlWs  CWrvqMT6fGbF4e0NoSOE  1SBVe5j4bWEXfMiQYsH9
# 9996  eHvhtMIg6uEQl32pj5o9  UCgl950VGsOfXtmEiAZ3  bO6rHgnolxkwjfYViB7q
# 9997  wthypCb3WB06XAJYekR8  IzSgEhpBOD8nkKwAoGYT  fgsL6FaXtTGKMlmVECqe
# 9998  S216sTinmXeAwkvUORo5  b9VlQC02fIdW8DZcv7RL  nW1xyl5MqbasAPidGtwI
# 9999  jPfMvLmTyicb8hOGFEek  21pkbQE9Bl3O0Nj6v5SC  XExNMLhCinUfVzOHraD9
#
#                      title                region  ... domain_website_click_1d  \
# 0     psJHRxzE5kS2ZwUgOKna  9LZ6YQrCh4SowkAKOpFf  ...                0.946144
# 1     NFSkpma0dYUlCV7ngiEP  EPKy5bDCel2hAd6zSv78  ...                0.408094
# 2     HW6xyvV5gDrIk0mtaubs  kTEpjbtRISuwHxdF0VKA  ...                0.137916
# 3     tc8nObLwM3ZqBxU0lKCV  LpI1Gtg0quFyKCQlEBcT  ...                0.709699
# 4     5TFouhxA0v4jVZ9Qt6EK  ZIHwSxruBLvA8Cd7MDYV  ...                0.606441
# ...                    ...                   ...  ...                     ...
# 9995  woPauhtpWL6I7EnOSx4D  R9qDXTJ147uefBz2QKd8  ...                0.354468
# 9996  Hgiq1TXc6fBM0KtvFy28  1YQ8NSdvDPszZ4cF37nX  ...                0.634423
# 9997  vN7DYcTSE2ztBm1qWau6  G5lyJnKTIhZbcrSv84uD  ...                0.627181
# 9998  zwsLvkRFVSpMBA9IWTqt  PsC8o4dhxfJe9ky6KLlb  ...                0.393747
# 9999  7RN4CYh6mPlg0LbtKXJu  AJ2y6kcw1KR9tXQlIrG8  ...                0.600836
#
#      domain_website_exp_1d domain_website_click_3d domain_website_exp_3d  \
# 0                 0.103943                0.697057              0.835622
# 1                 0.796093                0.531365              0.306002
# 2                 0.483957                0.082523              0.330797
# 3                 0.331744                0.969565              0.508447
# 4                 0.396516                0.289412              0.419054
# ...                    ...                     ...                   ...
# 9995              0.853486                0.599362              0.896752
# 9996              0.815318                0.330612              0.884765
# 9997              0.398546                0.648544              0.414315
# 9998              0.168946                0.895252              0.185574
# 9999              0.736822                0.034554              0.453604
#
#      domain_website_click_5d domain_website_exp_5d domain_website_click_7d  \
# 0                 wVnJXdoBRY            gPuxfzqjVl              HNQhVUEKuz
# 1                 YtBAnhxQsE            tuWNfVbCrK              COtoxJVTPz
# 2                 BEmxgTMvZC            DjmrOAQnBJ              ZpJMYUnRbS
# 3                 AVzibNoWYM            riCXBTDpbh              bfXWIODQmk
# 4                 bIFpxAhiDM            QEewBPxJVR              taXZbughdo
# ...                      ...                   ...                     ...
# 9995              EHvfYTiXoZ            uAvYxlHVbZ              ORdZNQHKuo
# 9996              OWmvzstXpq            LTboIcFfhd              mMzCHcjLyk
# 9997              DjCpViEXhG            ARTxVeuyWX              MarCeJmjVE
# 9998              LaSzMYPjWH            WkLpStXJnZ              OTiEWldJHj
# 9999              lFEznvYUWa            usKXSjLtJF              ftiXKmJqQg
#
#      domain_website_exp_7d hist_doc_id source_sample.label
# 0               fMktwSQGYx  pBLcsZrUGu         yAilT:jRWJB
# 1               OSfPXKYjDl  ThaeSJtwLX         sXEgt:Vwxns
# 2               DAYNFLvswe  hqYTSpfHri         ATGNo:hNdfe
# 3               WjSyNqYceR  QYebTdRwZS   EAkiQ:xEkMz:HXalE
# 4               qBTUkutlJD  NXiqYGmxCU               FIlxp
# ...                    ...         ...                 ...
# 9995            UaPQmEAzGs  QjoRnYavtf               HOvtS
# 9996            zKtYMuUcnm  YeRScWFEHr   SLGzu:DdvGQ:PztKs
# 9997            dOuBDHwzyS  EZeJipyDsF               ZYhbU
# 9998            ZdFzuRCDeP  CWIHARZOUV         eEBuh:aowvZ
# 9999            emjbRaHMUV  nvMiSxjmlV               tojAK
#
# [10000 rows x 41 columns]

# %% [markdown]
# ## 对指定列进行处理
#
# 首先对mdf的"hist_doc_id"列应用lambda函数，以冒号为分隔符进行切分，然后将mdf中的'x'替换成pd.NaT缺省值，前后结果对比如下：

# %%
print("before apply function to DataFrame.")
print(mdf["hist_doc_id"])
mdf["hist_doc_id"] = mdf["hist_doc_id"].apply(lambda x: x.split(':') if isinstance(x, str) else [])
mdf = mdf.replace("x", pd.NaT)
print("after apply function to DataFrame.")
print(mdf["hist_doc_id"])
# Out:
# before apply function to DataFrame.
# 0       pBLcsZrUGu
# 1       ThaeSJtwLX
# 2       hqYTSpfHri
# 3       QYebTdRwZS
# 4       NXiqYGmxCU
#            ...
# 9995    QjoRnYavtf
# 9996    YeRScWFEHr
# 9997    EZeJipyDsF
# 9998    CWIHARZOUV
# 9999    nvMiSxjmlV
# Name: hist_doc_id, Length: 10000, dtype: object
# after apply function to DataFrame.
# 0       [pBLcsZrUGu]
# 1       [ThaeSJtwLX]
# 2       [hqYTSpfHri]
# 3       [QYebTdRwZS]
# 4       [NXiqYGmxCU]
#             ...
# 9995    [QjoRnYavtf]
# 9996    [YeRScWFEHr]
# 9997    [EZeJipyDsF]
# 9998    [CWIHARZOUV]
# 9999    [nvMiSxjmlV]
# Name: hist_doc_id, Length: 10000, dtype: object

# %% [markdown]
# 新增“label”列，并将mdf的"source_sample.label"列数据拷贝至mdf的"label"列。
# 然后，截取mdf的后100条数据，根据"event_time"列的数值对整个mdf进行排序，再以(16 * 3)的维度分片。数据处理后结果如下：

# %%
mdf["label"] = mdf["source_sample.label"]
mdf = mdf[:-100]
print("before sort values to event_time column.")
print(mdf["event_time"])
mdf = mdf.sort_values("event_time")
print("*********************************************")
print("after sort values to event_time column.")
print(mdf["event_time"])
mdf.repartition((16, 3))
# Out:
# before sort values to event_time column.
# 0       qtmxuICEXp3lAYc81KUh
# 1       wAO3Krq0b4mtgG58hykD
# 2       582pskLef7cWwgBQC3Xo
# 3       SYrs72pBMVywlP0NQDEJ
# 4       kpiNSEC7fXG4hy9FsWgL
#                 ...
# 9895    6eMaWOcNPHEYVXop87LD
# 9896    v6fJpel0yX9zPucSDO2Q
# 9897    ZGFnHJ78Rr2bL1DCoeKO
# 9898    FX3Cmoj6fvNikbP9Tl7z
# 9899    sdD723z5UEoKfZecXwGP
# Name: event_time, Length: 9900, dtype: object
# *********************************************
# after sort values to event_time column.
# 9648    01C8Z6FwuyVbgXIWel5L
# 2391    01VBTdlYM5DRUZS4v2ys
# 5997    01X9n5l3vkdEUhQLWbSB
# 5708    01p2onA8ZjgGaQIiC57v
# 8177    02MKFh3LclpXECSJt4wo
#                 ...
# 2387    zxIlOpKb4GkZhwD0r6Cc
# 1431    zy50qrFa92DMeSRYpEoV
# 6813    zyBHp7RbOfw5AtSPXQLk
# 7156    zyatUqJ5CbnhAMe0GjNs
# 1339    zynZbGWaX0eBS5CTUw8c
# Name: event_time, Length: 9900, dtype: object

# %% [markdown]
# ## 数据转换
#
# 去掉mdf的索引，新增"is_training"列，将数据的前70%设为训练数据，其他数据标记为非训练数据。然后删除稠密特征列，将缺省值填充为-1。源码及运行结果如下:

# %%
mdf = mdf.reset_index(drop=True)
m_train_len = int(len(mdf) * 0.7)
mdf["is_training"] = [1] * m_train_len + [0] * (len(mdf) - m_train_len)
print("before dropping dense_feat_names columns.")
print(mdf.shape)
sparse_feat_names = ['user_id', 'doc_id', 'lang_type', 'domain_website', 'url_drop_last_slash', 'url',
                     'title', 'region', 'dtype', 'tags', 'topics', 'categ', 'second_class', 'orgCateg',
                     'hwSourceId', 'level2_topic', 'level2_main_topic', 'level3_topic', 'level3_main_topic',
                     'keyword_for_feed', 'entities']
dense_feat_names = ['pt_d', 'quality', 'porn', 'duration', 'url_click_2h', 'url_click_4h', 'url_click_8h',
                    'url_click_12h', 'url_click_24h', 'domain_website_click_1d', 'domain_website_exp_1d',
                    'domain_website_click_3d', 'domain_website_exp_3d', 'domain_website_click_5d',
                    'domain_website_exp_5d', 'domain_website_click_7d', 'domain_website_exp_7d']
mdf = mdf.drop(columns=dense_feat_names)
print("after dropping dense_feat_names columns.")
print(mdf.shape)
mdf = mdf.fillna("-1")
# Out:
# before dropping dense_feat_names columns.
# (9900, 43)
# after dropping dense_feat_names columns.
# (9900, 26)

# %% [markdown]
# mdf的稀疏特征列应用自定义hash函数，对"doc_id"列去重后，删除原index，并在第20列插入"inserted"列，数据为numpy随机数。源码及运行结果如下:

# %%
def hash_item(val, item_size=10000000, offset=0):
    if isinstance(val, str):
        return abs(int(hashlib.sha256(val.encode('utf-8')).hexdigest(), 16)) % item_size
    return abs(hash(val)) % item_size + offset
print("before apply hash_item function to sparse_feat_names columns.")
print(mdf[sparse_feat_names])
mdf[sparse_feat_names] = mdf[sparse_feat_names].applymap(hash_item)
print("after apply hash_item function to sparse_feat_names columns.")
print(mdf[sparse_feat_names])
mdf = mdf.drop_duplicates(subset=['doc_id'])
mdf = mdf.reset_index(drop=True)

np.random.seed(100)
data = np.random.rand(len(mdf))
mdf.insert(20, "inserted", pd.Series(data))
# Out:
# before apply hash_item function to sparse_feat_names columns.
#        user_id    doc_id  lang_type  domain_website   url_drop_last_slash  \
# 0      5974447  95207556   12864936         8124794  WtFlngb2dN5Dm7fsUpyG
# 1     13716918  75778363   63811234        94888995  vXJYGfl3dKN7DtITpAhL
# 2     56322769  55593192   12183088        11061708  AsfnYBwd5lJKI9MyvXHW
# 3     93774815  18831418   16874517        57356600  b8vJVhksqAGmfdUaYyIC
# 4     19501375   1783264   51892125        42043337  mFfTaJy52R4gh7uCMDsP
# ...        ...       ...        ...             ...                   ...
# 9895  87091601  82490967   25242193        72908750  bS4j7dIoDwaQ20ifPzLA
# 9896  50122756  80922387   71099054         8371814  d3U8tB5opcAz9VXrJ1Pi
# 9897  87105678  67008910   41511537        59187673  KNBmfPe4Cg957UA3RhcD
# 9898  40712385  57465396   31103361        71897453  HgcBkeT7fWuyjF5nP6tR
# 9899  93098460  48021476   46309165        50365957  2tXaWcK4xo91BORbGHSz
#
#                        url                 title                region  \
# 0     X3ywHIGgiL5UqlK2zt4E  p2CIVUngd8GQRt9lL6O3  lRpZS6tYTgzKckjxM91q
# 1     5K4R3Qte6HPJLsYGbyg2  OGuHxj0tNsCzQlWkdEw3  CIuLWhnZ2yws6StDie89
# 2     5EgPG18jduhKWJspSN2D  EKBg0jzwsvr4fquRiFI2  2jdXnLDtGa0JlsZHMcym
# 3     8mg1apATDMPFuLzs7R6c  GOCUogveBkAIzDS52fQy  dpUYkiR4Bws1PZEJAnTO
# 4     01RoXdLbMtpJVmlWKhze  5rTzoR4AtXDjVOuSM6xB  OtMJgh6pToav5WCki8rN
# ...                    ...                   ...                   ...
# 9895  3Hgdl64xF8ikuwDavGeQ  58R7HLPWAODZs4631eN2  OXV8i5IfcKtSRn1UJrxu
# 9896  19jh4GCTabq7VWkeFp2Z  sx2ArVzCSJKDnwQpyOTF  kVeGNfHapubS0PEsJBt2
# 9897  Ii4jJT0k16Vs2mLpy9Ft  IgCuQJqi7Sv5Aslx6NV3  8u7tUaDN6PV3B0KLdIQS
# 9898  c9wusQFTno1RjM0NDyYq  ykfLowumDsVCXJW5BH6P  xlO8mt1jPBsMafCL4J3R
# 9899  I4ynr0qfg2hRmdWTSGAK  twqzcmAjig1PMbkrlhn7  XKLyaeSnc94GYuMk0CsB
#
#                      dtype                  tags  ...                 categ  \
# 0     SKmH9iVbyvBgeZpqLlnd  fmevCdl39rc8ITRHYWtk  ...  YTnDCUmJtLVz6id31qAw
# 1     KeklCOhiA5TQEpXc1d9B  hE6BRszZe8b1kpCWnD0j  ...  KVO6CWwS3s1QmDeHPozv
# 2     RhBoKmOvbYsPDEAJUgG0  4Se18FiP2qxGh6yYp3nR  ...  RjZu12dOrgWsfzwKI3AH
# 3     N4t8OwvkXA3R6b01jzCl  3ksN49wpTlKbLiXR0xcv  ...  wyl0nef8PAambvrSVDsM
# 4     iT4kx5eL0mwaCFsZvyYV  nWrQ1eE7T2MXjJ3d9lbq  ...  lxkcAoMwLhdRCSasr78m
# ...                    ...                   ...  ...                   ...
# 9895  YJbw56PLqQZm0Wha7Vzi  wpuLosxH695iXlcZkeNa  ...  0amC9pyWExVcurB8b4MK
# 9896  JzvaUIwPxfOQFScGmlEi  8psXVmzbGDarK1PYinOy  ...  tN9o840CD7GWsjIPLkFz
# 9897  2A1Se7CIFdfR0kPH8Dyj  tT6SuBiERI3ZVxoGJHsg  ...  Xsy5m2dKWQZeokhFADVY
# 9898  7bwotip8x1Dvs9e4RCaP  UbOnDXqYN2y6cCVJEvlF  ...  VCkwTaY1J7G0EPIQtcfg
# 9899  rnGJsvl2Q7fe8TY36SZd  GWnwL6sSeMO2DkqAF8rX  ...  o1zDisg0FvjtOPQ6xRTf
#
#               second_class              orgCateg            hwSourceId  \
# 0     b9AjC65sPwlLfH0XMrTS  fhMeQs32RWvD9JoXAkzw  oMlqSPUu20fFDbQCYcsW
# 1     ecDS8Qr9yYslBw3CMvZO  v2a8dcrkJSVxZHf7eAY6  xSkUPsi08ZtJQuXqEmO2
# 2     kxN5e3yPnTWAbmcMdIl2  iATXu93swqVhgyKmPndH  xCkA7KSu1O4sPrVJ9b0y
# 3     pz64XWadwZNvA9YJMG1f  nCEbU4XoYmkMiI9HGAfB  zGQFZO8BWl10MvroXTty
# 4     yKhiTEN0OncGxqzZr6Hj  MWsJpZ24tqRbBGPHcuVk  rM8DmYHwd3qyj4N09TGV
# ...                    ...                   ...                   ...
# 9895  dAFJH0DqtKyR8ajum7i6  DifgM3SoIWwpybmktHaC  ml0NRJQLXdnYif2V8Mk3
# 9896  iOSdpeI6HxN9nl18QArh  8vWZlxgf94Fjyr02hcH1  nKLfJQA3EbZoYeChVapF
# 9897  hCVbKLcXUFDur9TnxyRq  gkwUMbAfcrIX4QzJNFCl  1R4AFmloNbK87OiXZSd2
# 9898  AuiIM7bcTrC4NLtkjoFE  PeYhnlMHmEiNvgSra7dp  lgsh2i65FPEH8vbKqTpm
# 9899  qslKDgMGc3rpaSh19uy0  KEHCXG1vOlIcwVJZ4sdR  A4rdYMDzQy72gvRPl1N3
#
#      level2_topic level2_main_topic level3_topic level3_main_topic  \
# 0              RP                OG           ej                ay
# 1              NL                sJ           DE                ko
# 2              QH                Qd           ts                ZW
# 3              ba                MG           hz                BQ
# 4              dM                gJ           cA                bO
# ...           ...               ...          ...               ...
# 9895           cu                IS           Cj                cu
# 9896           hb                gK           Rg                xW
# 9897           gm                zO           jF                OX
# 9898           DR                ec           Cd                rO
# 9899           Ht                dm           St                TA
#
#      keyword_for_feed entities
# 0                  ni       -1
# 1                  nj        d
# 2                  Ky        e
# 3                  Wr        e
# 4                  VF        c
# ...               ...      ...
# 9895               nR        b
# 9896               eN       -1
# 9897               Hc        e
# 9898               Su        e
# 9899               Gt        d
#
# [9900 rows x 21 columns]
# after apply hash_item function to sparse_feat_names columns.
#       user_id   doc_id  lang_type  domain_website  url_drop_last_slash  \
# 0     5974447  5207556    2864936         8124794              4121831
# 1     3716918  5778363    3811234         4888995              5678421
# 2     6322769  5593192    2183088         1061708              4161458
# 3     3774815  8831418    6874517         7356600               970599
# 4     9501375  1783264    1892125         2043337              5343680
# ...       ...      ...        ...             ...                  ...
# 9895  7091601  2490967    5242193         2908750               573792
# 9896   122756   922387    1099054         8371814              9142137
# 9897  7105678  7008910    1511537         9187673              4936605
# 9898   712385  7465396    1103361         1897453              1925697
# 9899  3098460  8021476    6309165          365957              2438502
#
#           url    title   region    dtype     tags  ...    categ  second_class  \
# 0     2028796  1145205  6772198   836122  6975599  ...  6657657       4650720
# 1     6740971  7770502  2433092  9847403  9091151  ...  2064678       7269943
# 2     8807838  3298805   111779  3837449  3134637  ...    54409       8383232
# 3     6512686  5345977  2849998  3245824  5518176  ...  3293608        910229
# 4     8987200  5295644  5037589  9105405   198322  ...  6798282       4412270
# ...       ...      ...      ...      ...      ...  ...      ...           ...
# 9895   608686   761835  3220432  9661195  6647741  ...  4037663       8915410
# 9896  5561354  7642273  6779996   776045  6469141  ...  4038239       9609077
# 9897  6496482  3259066  4852267  1296398  1767594  ...  9685326       2750380
# 9898  6249127  7436690  7698305  5973878  5295148  ...  6636634       3302935
# 9899  4233364  7652513  3880402  8577297  6899976  ...  9532598       2629175
#
#       orgCateg  hwSourceId  level2_topic  level2_main_topic  level3_topic  \
# 0      4910548     5609897       5468871            1612923       4749144
# 1       374964     1909431        714659            7582008       2950699
# 2      2219596     6536745       6587248             388911       6980132
# 3       566510     7924765       5444800            1704805       5539944
# 4      5120851     3138516       5252435            4707772       5906428
# ...        ...         ...           ...                ...           ...
# 9895     72883     6453009       9238989            5878603       2391700
# 9896   8943616     7739445       1478102            7965949       7490622
# 9897   1706464     1478460       7980404            6697782       1194161
# 9898   1373083     3949097       9573895            6195085       1550234
# 9899   8980830     4615410       9693190            8619964       6992196
#
#       level3_main_topic  keyword_for_feed  entities
# 0                618275           1897351   5734500
# 1               1079486           7771558   9981540
# 2               3502661           6109775   9201130
# 3               2915006           2147164   9201130
# 4               3687391           7546942   5618758
# ...                 ...               ...       ...
# 9895            9238989           4525965   2471965
# 9896            2591508           6115093   5734500
# 9897            6096667           6678001   9201130
# 9898            8681717           5917551   9201130
# 9899            5271468           7626946   9981540
#
# [9900 rows x 21 columns]

# %% [markdown]
# 至此，数据预处理，以及特征工程等操作（去重，应用转换函数，填充缺省值，新增数据列和分割数据集等）已完成，处理好的数据即可传入模型进行训练。
